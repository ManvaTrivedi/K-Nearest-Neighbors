# %%
# To load the Pandas libraries as an alias 'pds' 
import pandas as pds
# To load the numpy libraries as an alias 'npy' 
import numpy as npy
# Importing Label Encoder for encoding categorical feature
from sklearn.preprocessing import LabelEncoder
import math
from decimal import Decimal

#Function to Calculate Euclidean Distance
def Calc_Euclidean_Dist(TestData, TrainData):
    dist = 0
    for i in range(TrainData.shape[0]):
        dist = dist + (TestData[i] - TrainData[i])**2
    return math.sqrt(dist)

#Function to Calculate Manhattan Distance
def Calc_Manhattan_Dist(TestData, TrainData):
    dist = 0
    for i in range(TrainData.shape[0]):
        dist = dist + abs(TrainData[i] - TestData[i])
    return dist

# Function to calculate mean squared error used to calculate RMSE value
def mse(actual: npy.ndarray, predicted: npy.ndarray):
    return npy.mean(npy.square(actual - predicted))/len(actual)

# RMSE(Root Mean Squared Error) function to calculate accuracy of the model
def Calc_Accuracy(true_value, predicted_value):
    return npy.sqrt(mse(true_value, predicted_value)) 

# Function to get weights for applying weighted KNN
def  Weight(A):
    return 1/A**2
    if 0.001>A:
        return 1.0
    else:
        return 1/A**2
    
# Function to to apply Weighted KNN algorithm on continuous features
def weighted_knn_num(TrainData, TrainLabels, TestData, col_name, dist_methd):
    # Array initialisation to get the predicted labels and apply distance measures
    predicted_labels = []
    for i in range(len(TestData)): 
        dist_list = []
        for j in range(len(TrainData)):
            # If distance measure is Euclidean call function to calculate Euclidean distance
            if (dist_methd == 'Euclidean'):
                dist = Calc_Euclidean_Dist(TestData[i], TrainData[j])
            # If distance measure is Manhattan call function to calculate Manhattan distance
            elif (dist_methd == 'Manhattan'):
                dist = Calc_Manhattan_Dist(TestData[i], TrainData[j])
            # Assigning weights
            dist_list.append([Weight(dist),TrainLabels[j]])
        
        #numerical
        # Adding up the weights for each label and dividing by the individual weight to return respective predicted labels
        sigma_WL=0
        sigma_W=0
        for it in dist_list:
            w=it[0]
            l=it[1]
            sigma_WL+=w*l
            sigma_W+=w
        
        ans = sigma_WL/sigma_W
           
        predicted_labels.append(ans)
    return predicted_labels

# Function to to apply Weighted KNN algorithm on categorical features
def weighted_knn_cat(TrainData,TrainLabels, TestData, col_name, dist_methd):
    # Array initialisation to get the predicted labels and apply distance measures
    predicted_labels = []
    for i in range(len(TestData)): 
        dist_list = []
        for j in range(len(TrainData)):
            # If distance measure is Euclidean call function to calculate Euclidean distance
            if (dist_methd == 'Euclidean'):
                dist = Calc_Euclidean_Dist(TestData[i], TrainData[j])
            # If distance measure is Manhattan call function to calculate Manhattan distance
            elif (dist_methd == 'Manhattan'):
                dist = Calc_Manhattan_Dist(TestData[i], TrainData[j])
            # Assigning weights
            dist_list.append([Weight(dist),TrainLabels[j]])
  
        #catagorical
        # Adding up the weights for each label to count votes and return respective predicted labels
        votes = {}
        for it in dist_list:
            w=it[0]
            l=it[1]
            il = w*l
            if il in votes.keys():
                votes[l]+=w
            else: 
                votes[l]=w
                
        #print(votes)
        # Getting label and value of the member which has maximum voting count
        maxx_count = 0
        maxx_count_label = 0
        for label,count in votes.items():
            if count >= maxx_count:
                maxx_count_label = label
                maxx_count = count           
        
        ans = maxx_count_label
            
        predicted_labels.append(ans)
    return predicted_labels

# Function to to apply KNN algorithm on categorical features
def knn_cat(TrainData,TrainLabels, TestData, k, col_name, dist_methd):
    # Array initialisation to get the predicted labels and apply distance measures
    predicted_labels = []
    for i in range(len(TestData)): 
        dist_list = []
        for j in range(len(TrainData)):
            # If distance measure is Euclidean call function to calculate Euclidean distance
            if (dist_methd == 'Euclidean'):
                dist = Calc_Euclidean_Dist(TestData[i], TrainData[j])
            # If distance measure is Manhattan call function to calculate Manhattan distance
            elif (dist_methd == 'Manhattan'):            
                dist = Calc_Manhattan_Dist(TestData[i], TrainData[j])
            
            dist_list.append([dist,TrainLabels[j]])

        dist_list.sort()
        #predicted_labels.append(ans)   

        #Initializing a dictionary to store key value pairs of the list and apply concept of voting within list members
        votes = {}
        for x in range(K):
            if dist_list[x][1] in votes.keys():
                # incrementing the count of votes for that value if it exists
                votes[dist_list[x][1]] = votes[dist_list[x][1]] + 1
            else: 
                # initializing the count of votes for that value if it does not exist
                votes[dist_list[x][1]]=1
        
        # Getting label and value of the member which has maximum voting count
        maxx_count = 0
        maxx_count_label = 0
        for label,count in votes.items():
            if count >= maxx_count:
                maxx_count_label = label
                maxx_count = count
            
        predicted_labels.append(maxx_count_label)
    return predicted_labels

# Function to to apply KNN algorithm on continuous features
def knn_num(TrainData,TrainLabels, TestData, k, col_name, dist_methd):
    # Array initialisation to get the predicted labels and apply distance measures
    predicted_labels = []
    for i in range(len(TestData)): 
        dist_list = []
        for j in range(len(TrainData)):
            # If distance measure is Euclidean call function to calculate Euclidean distance
            if (dist_methd == 'Euclidean'):
                dist = Calc_Euclidean_Dist(TestData[i], TrainData[j])
            # If distance measure is Manhattan call function to calculate Manhattan distance
            elif (dist_methd == 'Manhattan'):
                dist = Calc_Manhattan_Dist(TestData[i], TrainData[j])
            dist_list.append([dist,TrainLabels[j]])


        dist_list.sort()
        # Adding up the weights for each label and dividing by the individual weight to return respective predicted labels        
        ans=0
        for i in range(K):
            ans += dist_list[i][1]
        ans = ans/K

        predicted_labels.append(ans) 
        
    return predicted_labels

# %%
for K in [1,7,'Weight']:
    for col_name in ['Species','Weight','Height','Width']:
        for dist_methd in ['Euclidean','Manhattan']:
            
            #loading data
            Fish = pds.read_csv("Fish.csv")
            
            # Using encoding technique for categorical feature 'Species' to calculate distance measures
            label_encoder = LabelEncoder()
            Fish["Species"] = label_encoder.fit_transform(Fish["Species"])

            #Creating missingness in data by removing 5% values from dataset for all features
            Fish[col_name + '_N'] = Fish[col_name].sample(frac=0.95)
            
            # Taking non null values from in train and null values in test
            train = Fish[pds.isnull(Fish[col_name + '_N']) == False]
            test = Fish[pds.isnull(Fish[col_name + '_N'])]

            # Dropping the feature for which we created missingness in data to as we need to calculate distance considering other features except that one
            train_features = train.drop([col_name,col_name + '_N'],axis=1).values
            train_labels =  train[col_name].values
            
            # Dropping the feature for which we created missingness in data to as we need to calculate distance considering other features except that one
            test_features = test.drop([col_name,col_name + '_N'],axis=1).values
            test_labels =  test[col_name].values
            
            if K == 'Weight':
                if (col_name == 'Species'):
                    #print('Predicted labels for ' , col_name ,' using Weighted KNN and ', dist_methd, ' Distance: ' , weighted_knn_cat(train_features,train_labels, test_features, col_name, dist_methd))
                    ypred = weighted_knn_cat(train_features,train_labels, test_features, col_name, dist_methd)
                    scc = Calc_Accuracy(test_labels, npy.array(ypred))
                    print('Accuracy for feature',col_name,'using ',dist_methd,'Distance: ',scc)
                elif (col_name == 'Weight'):
                    #print('Predicted labels for ' , col_name ,' using Weighted KNN and ' , dist_methd, 'Distance: ' , weighted_knn_num(train_features,train_labels, test_features, col_name, dist_methd))
                    ypred = weighted_knn_num(train_features,train_labels, test_features, col_name, dist_methd)
                    scc = Calc_Accuracy(test_labels, npy.array(ypred))
                    print('Accuracy for feature',col_name,'using ',dist_methd,'Distance: ',scc)
                elif (col_name == 'Height'):
                    #print('Predicted labels for ' , col_name ,' using Weighted KNN and ' , dist_methd, 'Distance: ' , weighted_knn_num(train_features,train_labels, test_features, col_name, dist_methd))
                    ypred = weighted_knn_num(train_features,train_labels, test_features, col_name, dist_methd)
                    scc = Calc_Accuracy(test_labels, npy.array(ypred))
                    print('Accuracy for feature',col_name,'using ',dist_methd,'Distance: ',scc)
                elif (col_name == 'Width'):
                    #print('Predicted labels for ' , col_name ,' using Weighted KNN and ' , dist_methd, 'Distance: ' , weighted_knn_num(train_features,train_labels, test_features, col_name, dist_methd))      
                    ypred = weighted_knn_num(train_features,train_labels, test_features, col_name, dist_methd)
                    scc = Calc_Accuracy(test_labels, npy.array(ypred))
                    print('Accuracy for feature',col_name,'using ',dist_methd,'Distance: ',scc)
            else:
                if (col_name == 'Species'):
                    #print('Predicted labels for ' , col_name ,' using ', K,'NN and ', dist_methd, ' Distance: ' , knn_cat(train_features,train_labels, test_features, K, col_name, dist_methd))
                    ypred = knn_cat(train_features,train_labels, test_features, K, col_name, dist_methd)
                    scc = Calc_Accuracy(test_labels, npy.array(ypred))
                    print('Accuracy for feature',col_name,'using ',dist_methd,'Distance: ',scc)
                elif (col_name == 'Weight'):
                    #print('Predicted labels for ' , col_name ,' using ', K,'NN and ', dist_methd, ' Distance: ' , knn_num(train_features,train_labels, test_features, K, col_name, dist_methd))
                    ypred = knn_num(train_features,train_labels, test_features, K, col_name, dist_methd)
                    scc = Calc_Accuracy(test_labels, npy.array(ypred))
                    print('Accuracy for feature',col_name,'using ',dist_methd,'Distance: ',scc)
                elif (col_name == 'Height'):
                    #print('Predicted labels for ' , col_name ,' using ', K,'NN and ', dist_methd, ' Distance: ' , knn_num(train_features,train_labels, test_features, K, col_name, dist_methd))
                    ypred = knn_num(train_features,train_labels, test_features, K, col_name, dist_methd)
                    scc = Calc_Accuracy(test_labels, npy.array(ypred))
                    print('Accuracy for feature',col_name,'using ',dist_methd,'Distance: ',scc)
                elif (col_name == 'Width'):
                    #print('Predicted labels for ' , col_name ,' using ', K,'NN and ', dist_methd, ' Distance: ' , knn_num(train_features,train_labels, test_features, K, col_name, dist_methd))
                    ypred = knn_num(train_features,train_labels, test_features, K, col_name, dist_methd)
                    scc = Calc_Accuracy(test_labels, npy.array(ypred))
                    print('Accuracy for feature',col_name,'using ',dist_methd,'Distance: ',scc)
# Out:
# Accuracy for feature Species using  Euclidean Distance:  0.5448623679425842
# Accuracy for feature Species using  Manhattan Distance:  0.9185586535436918
# Accuracy for feature Weight using  Euclidean Distance:  14.322185587402505
# Accuracy for feature Weight using  Manhattan Distance:  56.75536868878574
# Accuracy for feature Height using  Euclidean Distance:  0.9059335376767437
# Accuracy for feature Height using  Manhattan Distance:  0.5589206055257313
# Accuracy for feature Width using  Euclidean Distance:  0.2548249754733629
# Accuracy for feature Width using  Manhattan Distance:  0.1305694319605473
# Accuracy for feature Species using  Euclidean Distance:  0.6846531968814576
# Accuracy for feature Species using  Manhattan Distance:  0.45069390943299864
# Accuracy for feature Weight using  Euclidean Distance:  24.952128912076777
# Accuracy for feature Weight using  Manhattan Distance:  18.766701745052472
# Accuracy for feature Height using  Euclidean Distance:  0.7046745683980223
# Accuracy for feature Height using  Manhattan Distance:  0.6767964563437928
# Accuracy for feature Width using  Euclidean Distance:  0.14386434972726564
# Accuracy for feature Width using  Manhattan Distance:  0.08698983038219743
# Accuracy for feature Species using  Euclidean Distance:  0.9013878188659973
# Accuracy for feature Species using  Manhattan Distance:  0.6123724356957945
# Accuracy for feature Weight using  Euclidean Distance:  31.664034211627452
# Accuracy for feature Weight using  Manhattan Distance:  34.19717036983889
# Accuracy for feature Height using  Euclidean Distance:  0.43645522626913935
# Accuracy for feature Height using  Manhattan Distance:  1.0496124695545026
# Accuracy for feature Width using  Euclidean Distance:  0.23276420563943828
# Accuracy for feature Width using  Manhattan Distance:  0.18262372578886663

# %%
for K in [1,7,'Weight']:
    for col_name in ['Species','Weight','Height','Width']:
        for dist_methd in ['Euclidean','Manhattan']:
            
            #loading data
            Fish = pds.read_csv("Fish.csv") 
            
            # Using encoding technique for categorical feature 'Species' to calculate distance measures
            label_encoder = LabelEncoder()
            Fish["Species"] = label_encoder.fit_transform(Fish["Species"])

            #Creating missingness in data by removing 10% values from dataset for all features
            Fish[col_name + '_N'] = Fish[col_name].sample(frac=0.90)
            
            # Taking non null values from in train and null values in test
            train = Fish[pds.isnull(Fish[col_name + '_N']) == False]
            test = Fish[pds.isnull(Fish[col_name + '_N'])]

            # Dropping the feature for which we created missingness in data to as we need to calculate distance considering other features except that one
            train_features = train.drop([col_name,col_name + '_N'],axis=1).values
            train_labels =  train[col_name].values

            # Dropping the feature for which we created missingness in data to as we need to calculate distance considering other features except that one
            test_features = test.drop([col_name,col_name + '_N'],axis=1).values
            test_labels =  test[col_name].values
            
            if K == 'Weight':
                if (col_name == 'Species'):
                    #print('Predicted labels for ' , col_name ,' using Weighted KNN and ', dist_methd, ' Distance: ' , weighted_knn_cat(train_features,train_labels, test_features, col_name, dist_methd))
                    ypred = weighted_knn_cat(train_features,train_labels, test_features, col_name, dist_methd)
                    scc = Calc_Accuracy(test_labels, npy.array(ypred))
                    print('Accuracy for feature',col_name,'using ',dist_methd,'Distance: ',scc)
                elif (col_name == 'Weight'):
                    #print('Predicted labels for ' , col_name ,' using Weighted KNN and ' , dist_methd, 'Distance: ' , weighted_knn_num(train_features,train_labels, test_features, col_name, dist_methd))
                    ypred = weighted_knn_num(train_features,train_labels, test_features, col_name, dist_methd)
                    scc = Calc_Accuracy(test_labels, npy.array(ypred))
                    print('Accuracy for feature',col_name,'using ',dist_methd,'Distance: ',scc)
                elif (col_name == 'Height'):
                    #print('Predicted labels for ' , col_name ,' using Weighted KNN and ' , dist_methd, 'Distance: ' , weighted_knn_num(train_features,train_labels, test_features, col_name, dist_methd))
                    ypred = weighted_knn_num(train_features,train_labels, test_features, col_name, dist_methd)
                    scc = Calc_Accuracy(test_labels, npy.array(ypred))
                    print('Accuracy for feature',col_name,'using ',dist_methd,'Distance: ',scc)
                elif (col_name == 'Width'):
                   #print('Predicted labels for ' , col_name ,' using Weighted KNN and ' , dist_methd, 'Distance: ' , weighted_knn_num(train_features,train_labels, test_features, col_name, dist_methd)) 
                    ypred = weighted_knn_num(train_features,train_labels, test_features, col_name, dist_methd)
                    scc = Calc_Accuracy(test_labels, npy.array(ypred))
                    print('Accuracy for feature',col_name,'using ',dist_methd,'Distance: ',scc)

            else:
                if (col_name == 'Species'):
                    #print('Predicted labels for ' , col_name ,' using ', K,'NN and ', dist_methd, ' Distance: ' , knn_cat(train_features,train_labels, test_features, K, col_name, dist_methd))
                    ypred = knn_cat(train_features,train_labels, test_features, K, col_name, dist_methd)
                    scc = Calc_Accuracy(test_labels, npy.array(ypred))
                    print('Accuracy for feature',col_name,'using ',dist_methd,'Distance: ',scc)
                elif (col_name == 'Weight'):
                    #print('Predicted labels for ' , col_name ,' using ', K,'NN and ', dist_methd, ' Distance: ' , knn_num(train_features,train_labels, test_features, K, col_name, dist_methd))
                    ypred = knn_num(train_features,train_labels, test_features, K, col_name, dist_methd)
                    scc = Calc_Accuracy(test_labels, npy.array(ypred))
                    print('Accuracy for feature',col_name,'using ',dist_methd,'Distance: ',scc)
                elif (col_name == 'Height'):
                    #print('Predicted labels for ' , col_name ,' using ', K,'NN and ', dist_methd, ' Distance: ' , knn_num(train_features,train_labels, test_features, K, col_name, dist_methd))
                    ypred = knn_num(train_features,train_labels, test_features, K, col_name, dist_methd)
                    scc = Calc_Accuracy(test_labels, npy.array(ypred))
                    print('Accuracy for feature',col_name,'using ',dist_methd,'Distance: ',scc)
                elif (col_name == 'Width'):
                    #print('Predicted labels for ' , col_name ,' using ', K,'NN and ', dist_methd, ' Distance: ' , knn_num(train_features,train_labels, test_features, K, col_name, dist_methd))
                    ypred = knn_num(train_features,train_labels, test_features, K, col_name, dist_methd)
                    scc = Calc_Accuracy(test_labels, npy.array(ypred))
                    print('Accuracy for feature',col_name,'using ',dist_methd,'Distance: ',scc)
# Out:
# Accuracy for feature Species using  Euclidean Distance:  0.29315098498896436
# Accuracy for feature Species using  Manhattan Distance:  0.5191639914323797
# Accuracy for feature Weight using  Euclidean Distance:  40.74736810902638
# Accuracy for feature Weight using  Manhattan Distance:  11.16010612628751
# Accuracy for feature Height using  Euclidean Distance:  0.858506685872335
# Accuracy for feature Height using  Manhattan Distance:  0.5471559154933583
# Accuracy for feature Width using  Euclidean Distance:  0.08492021370270157
# Accuracy for feature Width using  Manhattan Distance:  0.18110493828682586
# Accuracy for feature Species using  Euclidean Distance:  0.2724311839712921
# Accuracy for feature Species using  Manhattan Distance:  0.42389562394532926
# Accuracy for feature Weight using  Euclidean Distance:  17.972803779642472
# Accuracy for feature Weight using  Manhattan Distance:  17.264952135055726
# Accuracy for feature Height using  Euclidean Distance:  0.5727143466722723
# Accuracy for feature Height using  Manhattan Distance:  0.4983086156979375
# Accuracy for feature Width using  Euclidean Distance:  0.11978359409061531
# Accuracy for feature Width using  Manhattan Distance:  0.0962031328504884
# Accuracy for feature Species using  Euclidean Distance:  0.44633927678392815
# Accuracy for feature Species using  Manhattan Distance:  0.6465050270492876
# Accuracy for feature Weight using  Euclidean Distance:  19.047293309530186
# Accuracy for feature Weight using  Manhattan Distance:  14.009322468574902
# Accuracy for feature Height using  Euclidean Distance:  0.49547092410609705
# Accuracy for feature Height using  Manhattan Distance:  0.615604584088348
# Accuracy for feature Width using  Euclidean Distance:  0.15096793271311468
# Accuracy for feature Width using  Manhattan Distance:  0.11336897314286368

# %%
for K in [1,7,'Weight']:
    for col_name in ['Species','Weight','Height','Width']:
        for dist_methd in ['Euclidean','Manhattan']:
            
            #loading data
            Fish = pds.read_csv("Fish.csv") 
            
            # Using encoding technique for categorical feature 'Species' to calculate distance measures
            label_encoder = LabelEncoder()
            Fish["Species"] = label_encoder.fit_transform(Fish["Species"])

            #Creating missingness in data by removing 20% values from dataset for all features
            Fish[col_name + '_N'] = Fish[col_name].sample(frac=0.80)
            
            # Taking non null values from in train and null values in test
            train = Fish[pds.isnull(Fish[col_name + '_N']) == False]
            test = Fish[pds.isnull(Fish[col_name + '_N'])]

            # Dropping the feature for which we created missingness in data to as we need to calculate distance considering other features except that one
            train_features = train.drop([col_name,col_name + '_N'],axis=1).values
            train_labels =  train[col_name].values

            # Dropping the feature for which we created missingness in data to as we need to calculate distance considering other features except that one
            test_features = test.drop([col_name,col_name + '_N'],axis=1).values
            test_labels =  test[col_name].values
            
            if K == 'Weight':
                if (col_name == 'Species'):
                    #print('Predicted labels for ' , col_name ,' using Weighted KNN and ', dist_methd, ' Distance: ' , weighted_knn_cat(train_features,train_labels, test_features, col_name, dist_methd))
                    ypred = weighted_knn_cat(train_features,train_labels, test_features, col_name, dist_methd)
                    scc = Calc_Accuracy(test_labels, npy.array(ypred))
                    print('Accuracy for feature',col_name,'using ',dist_methd,'Distance: ',scc)
                elif (col_name == 'Weight'):
                    #print('Predicted labels for ' , col_name ,' using Weighted KNN and ' , dist_methd, 'Distance: ' , weighted_knn_num(train_features,train_labels, test_features, col_name, dist_methd))
                    ypred = weighted_knn_num(train_features,train_labels, test_features, col_name, dist_methd)
                    scc = Calc_Accuracy(test_labels, npy.array(ypred))
                    print('Accuracy for feature',col_name,'using ',dist_methd,'Distance: ',scc)
                elif (col_name == 'Height'):
                    #print('Predicted labels for ' , col_name ,' using Weighted KNN and ' , dist_methd, 'Distance: ' , weighted_knn_num(train_features,train_labels, test_features, col_name, dist_methd))
                    ypred = weighted_knn_num(train_features,train_labels, test_features, col_name, dist_methd)
                    scc = Calc_Accuracy(test_labels, npy.array(ypred))
                    print('Accuracy for feature',col_name,'using ',dist_methd,'Distance: ',scc)
                elif (col_name == 'Width'):
                    #print('Predicted labels for ' , col_name ,' using Weighted KNN and ' , dist_methd, 'Distance: ' , weighted_knn_num(train_features,train_labels, test_features, col_name, dist_methd))   
                    ypred = weighted_knn_num(train_features,train_labels, test_features, col_name, dist_methd)
                    scc = Calc_Accuracy(test_labels, npy.array(ypred))
                    print('Accuracy for feature',col_name,'using ',dist_methd,'Distance: ',scc)
            else:
                if (col_name == 'Species'):
                    #print('Predicted labels for ' , col_name ,' using ', K,'NN and ', dist_methd, ' Distance: ' , knn_cat(train_features,train_labels, test_features, K, col_name, dist_methd))
                    ypred = knn_cat(train_features,train_labels, test_features, K, col_name, dist_methd)
                    scc = Calc_Accuracy(test_labels, npy.array(ypred))
                    print('Accuracy for feature',col_name,'using ',dist_methd,'Distance: ',scc)
                elif (col_name == 'Weight'):
                    #print('Predicted labels for ' , col_name ,' using ', K,'NN and ', dist_methd, ' Distance: ' , knn_num(train_features,train_labels, test_features, K, col_name, dist_methd))
                    ypred = knn_num(train_features,train_labels, test_features, K, col_name, dist_methd)
                    scc = Calc_Accuracy(test_labels, npy.array(ypred))
                    print('Accuracy for feature',col_name,'using ',dist_methd,'Distance: ',scc)
                elif (col_name == 'Height'):
                    #print('Predicted labels for ' , col_name ,' using ', K,'NN and ', dist_methd, ' Distance: ' , knn_num(train_features,train_labels, test_features, K, col_name, dist_methd))
                    ypred = knn_num(train_features,train_labels, test_features, K, col_name, dist_methd)
                    scc = Calc_Accuracy(test_labels, npy.array(ypred))
                    print('Accuracy for feature',col_name,'using ',dist_methd,'Distance: ',scc)
                elif (col_name == 'Width'):
                    #print('Predicted labels for ' , col_name ,' using ', K,'NN and ', dist_methd, ' Distance: ' , knn_num(train_features,train_labels, test_features, K, col_name, dist_methd))
                    ypred = knn_num(train_features,train_labels, test_features, K, col_name, dist_methd)
                    scc = Calc_Accuracy(test_labels, npy.array(ypred))
                    print('Accuracy for feature',col_name,'using ',dist_methd,'Distance: ',scc)
# Out:
# Accuracy for feature Species using  Euclidean Distance:  0.32021721143623744
# Accuracy for feature Species using  Manhattan Distance:  0.38654115240165565
# Accuracy for feature Weight using  Euclidean Distance:  24.275986197462196
# Accuracy for feature Weight using  Manhattan Distance:  10.321222163732598
# Accuracy for feature Height using  Euclidean Distance:  0.4938264541183567
# Accuracy for feature Height using  Manhattan Distance:  0.39840886750061805
# Accuracy for feature Width using  Euclidean Distance:  0.08634620879597145
# Accuracy for feature Width using  Manhattan Distance:  0.09724283643683605
# Accuracy for feature Species using  Euclidean Distance:  0.3029799910885206
# Accuracy for feature Species using  Manhattan Distance:  0.29973947020704494
# Accuracy for feature Weight using  Euclidean Distance:  25.603318096695723
# Accuracy for feature Weight using  Manhattan Distance:  22.135967349592654
# Accuracy for feature Height using  Euclidean Distance:  0.36481790891530813
# Accuracy for feature Height using  Manhattan Distance:  0.5050379019232376
# Accuracy for feature Width using  Euclidean Distance:  0.08093660872864404
# Accuracy for feature Width using  Manhattan Distance:  0.07766312127240108
# Accuracy for feature Species using  Euclidean Distance:  0.38400642898264087
# Accuracy for feature Species using  Manhattan Distance:  0.414578098794425
# Accuracy for feature Weight using  Euclidean Distance:  33.50892678651014
# Accuracy for feature Weight using  Manhattan Distance:  16.62057230654118
# Accuracy for feature Height using  Euclidean Distance:  0.45069861853749854
# Accuracy for feature Height using  Manhattan Distance:  0.3487184411320513
# Accuracy for feature Width using  Euclidean Distance:  0.09665042335426986
# Accuracy for feature Width using  Manhattan Distance:  0.07105055869917189
